# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df= pd.read_csv('/kaggle/input/onlineprofit-prediction/online(profit-prediction).csv')

# %%
df     #or df.df.head() = show 1st sum of row
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum() #check is it null ot not
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# # Separate X,Y

# %%
#dependent(Y) and independent(X) variable Separation (without profit all independent )

x = df.drop(['Profit'],axis=1)
x
# Out:
#     Marketing Spend  Administration  Transport     Area
# 0         114523.61       136897.80  471784.10    Dhaka
# 1         162597.70       151377.59  443898.53      Ctg
# 2         153441.51       101145.55  407934.54  Rangpur
# 3         144372.41       118671.85  383199.62    Dhaka
# 4         142107.34        91391.77  366168.42  Rangpur
# 5         131876.90        99814.71  362861.36    Dhaka
# 6         134615.46       147198.87  127716.82      Ctg
# 7         130298.13       145530.06  323876.68  Rangpur
# 8         120542.52       148718.95  311613.29    Dhaka
# 9         123334.88       108679.17  304981.62      Ctg
# 10        101913.08       110594.11  229160.95  Rangpur
# 11        100671.96        91790.61  249744.55      Ctg
# 12         93863.75       127320.38  249839.44  Rangpur
# 13         91992.39       135495.07  252664.93      Ctg
# 14        119943.24       156547.42  256512.92  Rangpur
# 15        165349.20       122616.84  261776.23    Dhaka
# ...

# %%
y =df['Profit']
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %% [markdown]
# # One hot encoding

# %%
#convert the Catagorical column to numeric data by get_dummies func(One hot encoding)
city = pd.get_dummies(x['Area'],drop_first = True) #x['Area'] = string to numeric
city
#"Ctg doesn't appear because all the rows contain true(1) or false(0) either Dhaka or Rangpur
# Out:
#     Dhaka  Rangpur
# 0    True    False
# 1   False    False
# 2   False     True
# 3    True    False
# 4   False     True
# 5    True    False
# 6   False    False
# 7   False     True
# 8    True    False
# 9   False    False
# 10  False     True
# 11  False    False
# 12  False     True
# 13  False    False
# 14  False     True
# 15   True    False
# 16  False    False
# 17   True    False
# 18  False     True
# 19   True    False
# 20  False    False
# 21   True    False
# 22  False     True
# 23  False     True
# 24   True    False
# 25  False    False
# 26  False     True
# 27   True    False
# 28  False     True
# 29   True    False
# 30  False     True
# 31   True    False
# 32  False    False
# 33  False     True
# 34  False    False
# 35   True    False
# 36  False     True
# 37  False    False
# 38   True    False
# 39  False    False
# 40  False    False
# 41  False     True
# 42  False    False
# 43   True    False
# 44  False    False
# 45   True    False
# ...

# %%
#Drop the area coulmn
x = x.drop('Area',axis=1)
x
# Out:
#     Marketing Spend  Administration  Transport
# 0         114523.61       136897.80  471784.10
# 1         162597.70       151377.59  443898.53
# 2         153441.51       101145.55  407934.54
# 3         144372.41       118671.85  383199.62
# 4         142107.34        91391.77  366168.42
# 5         131876.90        99814.71  362861.36
# 6         134615.46       147198.87  127716.82
# 7         130298.13       145530.06  323876.68
# 8         120542.52       148718.95  311613.29
# 9         123334.88       108679.17  304981.62
# 10        101913.08       110594.11  229160.95
# 11        100671.96        91790.61  249744.55
# 12         93863.75       127320.38  249839.44
# 13         91992.39       135495.07  252664.93
# 14        119943.24       156547.42  256512.92
# 15        165349.20       122616.84  261776.23
# 16         78013.11       121597.55  264346.06
# 17         94657.16       145077.58  282574.31
# 18         91749.16       114175.79  294919.57
# ...

# %%
x= pd.concat([x,city],axis=1)
x
# Out:
#     Marketing Spend  Administration  Transport  Dhaka  Rangpur
# 0         114523.61       136897.80  471784.10   True    False
# 1         162597.70       151377.59  443898.53  False    False
# 2         153441.51       101145.55  407934.54  False     True
# 3         144372.41       118671.85  383199.62   True    False
# 4         142107.34        91391.77  366168.42  False     True
# 5         131876.90        99814.71  362861.36   True    False
# 6         134615.46       147198.87  127716.82  False    False
# 7         130298.13       145530.06  323876.68  False     True
# 8         120542.52       148718.95  311613.29   True    False
# 9         123334.88       108679.17  304981.62  False    False
# 10        101913.08       110594.11  229160.95  False     True
# 11        100671.96        91790.61  249744.55  False    False
# 12         93863.75       127320.38  249839.44  False     True
# 13         91992.39       135495.07  252664.93  False    False
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.25,random_state=0)

# %%
regressor = LinearRegression() # create an object name of regressor

# %%
regressor.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ytest
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# 33     96778.92
# 35     96479.51
# 26    105733.54
# Name: Profit, dtype: float64

# %%
pred = regressor.predict(xtest)
pred
# Out:
# array([103501.0825284 , 128011.28068627, 126695.43891127,  70573.91718775,
#        173381.96874259, 124238.07860872,  69298.09250304,  98399.41936876,
#        116419.1480864 , 161430.98134847,  94740.73303076,  89920.22800514,
#        105956.86065332])

# %%
regressor.score(xtest,ytest)
# Out:
# 0.884097862392347

# %% [markdown]
# # R-Squared Value

# %%
score=r2_score(ytest,pred)

# %%
score
# Out:
# 0.884097862392347
